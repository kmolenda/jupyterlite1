-- %% [markdown]
-- ---
-- title: Lab. Baza videoDVD w SQLite
-- subtitle: Operacje `SELECT` na relacyjnej bazie danych w JupyterLite (XEUS-SQLite)
-- author:
--   - name: Krzysztof Molenda
--     affiliations: URK/WIPiE/KIPLiIS
--     email: krzysztof.molenda@urk.edu.pl
-- date: 2026/03/02
-- ---
--
-- ---

-- %% [markdown]
-- :::{admonition} Ważne
-- :class: warning
--
-- * Niniejsze ćwiczenie opracowane jest w formie interaktywnego notatnika Jupyter wykorzystującego kernel `xeus-xsqlite`, obsługującego relacyjne bazy danych w formacie `sqlite`.
-- * Zadania należy wykonywać **po kolei**.
-- * Zawsze można zrestartować jądro Jupyter Notebooka i wyczyścić wszystkie wyniki obliczeń (komenda `Kernel -> Restart & Clear Output`).
-- :::

-- %% [markdown]
-- Diagram ER bazy danych `videoDVD`
--
-- ![image.png](attachment:bdb4dad4-eb48-45c0-a9d1-a4af18b1841e.png)

-- %% [markdown]
-- Załadowanie bazy danych do pamięci notatnika

-- %%
%LOAD videoDVDv2-km-lab.sqlite3.db

-- %%
-- sprawdzenie: wypisanie wszytkich informacji z tabeli klienci
SELECT *
FROM Klienci
ORDER BY NazwiskoKlienta, ImieKlienta;

-- %% [markdown]
-- ## Zadanie 1
--
-- Wprowadź kwerendę wypisującą nazwiska i imiona wszystkich klientów posortowane rosnąco według nazwiska, a następnie według imienia.
--
-- Wynik powinien mniej więcej wyglądać tak:
--
-- ![image.png](attachment:4ce540ca-8f09-4122-9474-939ee9dcb235.png)

-- %%
-- Nazwiska i imiona wszystkich klientów posortowane rosnąco według nazwiska, a następnie według imienia.
SELECT ..., ...
FROM ...
ORDER BY ..., ...;

-- %% [markdown]
-- ## Zadanie 2
--
-- Wprowadź kwerendę opisaną poniższym warunkiem:
--
-- Nazwisko i imię klienta oddzielone spacją jako kolumna o nazwie `Nazwisko i imię`, adres klienta obejmujący ulicę, kod pocztowy oraz miejscowość (ulica oddzielona przecinkiem i jedną spacją od kodu, pojedyncza spacja między kodem pocztowym i miejscowością) jako kolumna o nazwie `Adres`, dla klientów którzy wpisani zostali do systemu po 15 maja 2007 roku, posortowane malejąco według daty wprowadzenia, a następnie rosnąco według adresu.
--
-- Do opisu wyprowadzanego wyniku sugeruj się przykładem.
--
-- Podpowiedź:
--
-- - do sklejania napisów użyj operatora konkatenacji `||`
-- - daty w SQLite zapamiętane są w formie tekstu zgodnie z normą ISO 8601 (data reprezentowana w formie ciągu znaków ustawionych w porządku od najbardziej znaczących (rok) do najmniej znaczących, np. `2000-12-01`), zatem można je porównywać tak, jak porównuje się napisy.
--
-- ![image.png](attachment:3542f362-ecff-4506-b6e4-78d67c600a2a.png)

-- %%
-- wpisz kod poniżej
SELECT ...
    ...

-- %% [markdown]
-- ## Zadanie 3
--
-- Wprowadź kwerendę opisaną poniższym warunkiem:
--
-- Wszystkie dane klientów-kobiet, oprócz pola `Plec`. Kolumny wyniku o nazwach i w kolejności zdefiniowanej w stosownej tabeli bazy danych, wiersze w kolejności rosnącej określonej przez klucz główny.
--
-- Do opisu wyprowadzanego wyniku sugeruj się przykładem.
--
-- ![image.png](attachment:95c1ee26-3a85-452c-bcce-33356a835698.png)

-- %%
-- wpisz kod poniżej
SELECT ...
    ...

-- %% [markdown]
-- ## Zadanie 4
--
-- Wprowadź kwerendę opisaną poniższym warunkiem:
--
-- Imiona, nazwiska i daty przyjęcia do wypożyczalni mężczyzn, zapisanych w 2008 roku. Wyniki wypisz rosnąco ze względu na datę przyjęcia.
--
-- Uwaga: daty i czas w SQLite zapamiętane są w formie tekstu zgodnie z normą ISO 8601 (data reprezentowana w formie ciągu znaków ustawionych w porządku od najbardziej znaczących (rok) do najmniej znaczących (czyli sekund), np. `2000-12-01 00:00:00`), zatem można je porównywać tak, jak porównuje się napisy.
--
-- Do opisu wyprowadzanego wyniku sugeruj się przykładem.
--
-- ![image.png](attachment:bd2928d1-764e-437b-9d38-a6631209c4ab.png)

-- %%
-- wpisz kod poniżej
SELECT ...
    ...

-- %% [markdown]
-- ## Zadanie 5
--
-- Wprowadź kwerendę opisaną poniższym warunkiem:
--
-- Nazwiska, imiona i daty urodzenia klientów urodzonych w 1980 roku i później, posortowane rosnąco według daty urodzenia.
--
-- Do opisu wyprowadzanego wyniku sugeruj się przykładem.
--
-- Uwaga: daty i czas w SQLite zapamiętane są w formie tekstu zgodnie z normą ISO 8601 (data reprezentowana w formie ciągu znaków ustawionych w porządku od najbardziej znaczących (rok) do najmniej znaczących (czyli sekund), np. `2000-12-01 00:00:00`), zatem można je porównywać tak, jak porównuje się napisy.
--
-- ![image.png](attachment:0ec10b4e-f565-4d37-ab8e-73231300033f.png)

-- %%
-- wpisz kod poniżej
SELECT ...
    ...

-- %% [markdown]
-- ## Zadanie 6
--
-- Wprowadź kwerendę opisaną poniższym warunkiem:
--
-- Tytuły wszystkich hitów, uporządkowane malejąco ze względu na rok produkcji, a w przypadku filmów o tym samym roku produkcji - rosnąco ze względu na tytuł filmu.
--
-- Do opisu wyprowadzanego wyniku sugeruj się przykładem.
--
-- ![image.png](attachment:ec112848-7f9e-4d31-8149-cd8f6a445507.png)

-- %%
-- wpisz kod poniżej
SELECT ...
    ...

-- %% [markdown]
-- ## Zadanie 9
--
-- Wprowadź kwerendę opisaną poniższym warunkiem:
--
-- Tytuły filmów, których wypożyczenie kosztuje więcej niż 8 zł oraz opłatę za wypożyczenie na 1 dzień. Wyniki posortuj ze względu na opłatę malejąco, a w przypadku równych wartości opłaty - według tytułu rosnąco.
--
-- Do opisu wyprowadzanego wyniku sugeruj się przykładem.
--
-- ![image.png](attachment:13cfd685-7443-479c-a1ac-73541397aa60.png)

-- %%
-- wpisz kod poniżej
SELECT ...
    ...

-- %% [markdown]
-- ## Zadanie 10
--
-- Wprowadź kwerendę opisaną poniższym warunkiem:
--
-- Imiona i nazwiska klientów, którzy kiedykolwiek wypożyczyli płyty. Rekordy w tabeli wynikowej oznaczające tę samą osobę nie mogą się powtarzać, ale jeśli dwoje lub większa liczba klientów nosi to samo imię i nazwisko, powinni się pojawić osobno. Wyniki posortuj rosnąco ze względu nazwisko, a w przypadku tych samych nazwisk - według imienia rosnąco.
--
-- Do opisu wyprowadzanego wyniku sugeruj się przykładem.
--
-- ![image.png](attachment:22786510-4d9a-4511-88f6-a2b0e0c35cf2.png)

-- %%
-- wpisz kod poniżej
SELECT ...
    ...

-- %% [markdown]
-- ## Zadanie 11
--
-- Wprowadź kwerendę opisaną poniższym warunkiem:
--
-- Nazwiska i imiona klientów, którzy przetrzymują płytę dłużej niż jeden dzień. Każdy klient powinien pojawić się tyle razy, ile płyt przetrzymuje.
--
-- Wyniki posortuj rosnąco ze względu nazwisko, a w przypadku tych samych nazwisk - według imienia rosnąco.
--
--
-- UWAGA: w SQLite3
--
-- - aby uzyskać dzisiejszą datę, użyjesz funkcji `date('now')`,
-- - aby uzyskać datę wcześniejszą o 14 dni od wskazanej, np. `2022-02-10`, użyjesz `date('2022-02-10', '-14 days')`
-- - aby uzyskać datę jutrzejszą, napiszesz `date('now', +1 day')`
--
-- Do opisu wyprowadzanego wyniku sugeruj się przykładem.
--
-- ![image.png](attachment:5efd2f7b-115f-41ac-b0f5-e667e6e62f80.png)

-- %%
-- wpisz kod poniżej
SELECT ...
    ...

-- %% [markdown]
-- ## Zadanie 13
--
-- Wprowadź kwerendę opisaną poniższym warunkiem:
--
-- Nazwiska, imiona i adresy klientów (ulica, kod pocztowy, miejscowość), którzy aktualnie mają wypożyczone płyty. Każdy klient powinien pojawić się tylko raz.
--
-- Wyniki posortuj rosnąco ze względu nazwisko, a w przypadku tych samych nazwisk - według imienia, ulicy, kodu pocztowego i miejscowości rosnąco.
--
-- Do opisu wyprowadzanego wyniku sugeruj się przykładem.
--
-- ![image.png](attachment:1404e9ae-b827-4c48-b737-52e25f6cef78.png)

-- %%
-- wpisz kod poniżej
SELECT ...
    ...

-- %% [markdown]
-- ## Zadanie 14
--
-- Wprowadź kwerendę opisaną poniższym warunkiem:
--
-- Nazwiska i imiona klientów, którzy mają aktualnie wypożyczoną przynajmniej jedną płytę wraz z liczbą tych płyt. Jako tytuł tej ostatniej kolumny ma się pojawić Liczba płyt
--
-- Wyniki posortuj malejąco ze względu na liczbę płyt, a następnie rosnąco ze względu nazwisko i imię.
--
-- Do opisu wyprowadzanego wyniku sugeruj się przykładem.
--
-- ![image.png](attachment:42ce660e-7bff-436e-bdfc-bdca07652e39.png)

-- %%
-- wpisz kod poniżej
SELECT ...
    ...

-- %% [markdown]
-- ## Zadanie 16
--
-- Wprowadź kwerendę opisaną poniższym warunkiem:
--
-- Tytuły wszystkich komedii lub filmów obyczajowych zarejestrowanych w bazie, posortowane rosnąco. Każdy tytuł ma się pojawić tylko raz.
--
-- Wyniki posortuj rosnąco.
--
-- Do opisu wyprowadzanego wyniku sugeruj się przykładem.
--
-- ![image.png](attachment:17f2d2de-00a7-4fab-89a8-27f6cfd50388.png)

-- %%
-- wpisz kod poniżej
SELECT ...
    ...

-- %% [markdown]
-- ## Zadanie 18
--
-- Wprowadź kwerendę opisaną poniższym warunkiem:
--
-- Wszystkie tytuły oraz dla każdego z nich liczbę płyt, które posiada wypożyczalnia (wypożyczonych i nie wypożyczonych). Kolumnę zawierającą liczbę płyt nazwij `Liczba płyt`. Wyniki posortuj względem liczby płyt, a w przypadku równej ilości, według tytułu filmu.
--
-- Uwaga: w SQLite nie zaimplementowano operatora `RIGHT JOIN` (zamiast niego można odpowiednio użyć `LEFT JOIN`)
--
-- Do opisu wyprowadzanego wyniku sugeruj się przykładem.
--
-- ![image.png](attachment:13a26fa0-1c33-48e6-ba40-5b092bcbf8a6.png)

-- %%
-- wpisz kod poniżej
SELECT ...
    ...

-- %% [markdown]
-- ## Zadanie 25
--
-- Wprowadź kwerendę opisaną poniższym warunkiem:
--
-- Tytuły filmów, które nie były do tej pory ani raz wypożyczone.
--
-- Wyniki posortuj rosnąco.
--
-- Do opisu wyprowadzanego wyniku sugeruj się przykładem.
--
-- ![image.png](attachment:b2148a6d-2135-45b0-a38a-c8f41fcd201b.png)

-- %%
-- wpisz kod poniżej
SELECT ...
    ...

-- %% [markdown]
-- ## Zadanie 38
--
-- Wprowadź kwerendę opisaną poniższym warunkiem:
--
-- Identyfikatory, nazwiska i imiona klientów, którzy aktualnie posiadają wypożyczone płyty oraz nazwę nie zwróconego filmu i liczbę oznaczającą, ile już dni klient przetrzymuje płytę (w postaci liczby całkowitej). Do obliczeń przyjmij, że dzisiaj jest `2022-01-15`.
--
-- Pole obliczane nazwij `Liczba dni`. Dane w tabeli wynikowej posortuj malejąco względem liczby dni, a następnie rosnąco względem nazwiska i imienia.
--
-- Do opisu wyprowadzanego wyniku sugeruj się przykładem.
--
-- Uwaga: w dialekcie SQLite * nie zaimplementowano operatora RIGHT JOIN (zamiast niego można odpowiednio użyć `LEFT JOIN`) * liczbę dni pomiędzy dniem `2020-01-15` a np. zapamiętanym w polu `DataWypozyczenia`, obliczysz wyrażeniem: `CAST( julianday('2020-01-15') - julianday(DataWypozyczenia) AS INTEGER` )
--
-- ![image.png](attachment:7faacea0-fb8d-4814-b2d9-deaa3b52024c.png)

-- %%
-- wpisz kod poniżej
SELECT ...
    ...
